# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.libraryofshortstories.com/stories"

# %%
page = requests.get(url)

# %%
print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <meta name="application-name" content="library-of-short-stories">
#     <title>The Library - Library of Short Stories</title>
#     <meta name="description" content="Filter by genre, author and length or search directly by title. Arthur Conan Doyle, Edgar Allan Poe, H.P. Lovecraft and many more. ">
#     <meta name="web_author" content="Evan Lewis">
#     <meta name="keywords" content="Short Stories, read online, classics, library, public domain, free, Edgar Allan Poe, H P Lovecraft, Roald Dahl">
#
#     <link rel="apple-touch-icon" sizes="180x180" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-180x180.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-16x16.png">
#     <link rel="icon" type="image/png" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-32x32.png">
#     <link rel="shortcut icon" href="/favicon.ico">
#     <link rel="shortcut icon" sizes="16x16" href="/favicon.ico-16x16">
#     <meta name="msapplication-TileImage" content="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-144x144.png">
#
#     <link rel="canonical" href=https:&#x2F;&#x2F;www.libraryofshortstories.com&#x2F;stories />
#
#     <meta property="og:title" content="The Library - Library of Short Stories" />
#     <meta property="og:description" content="Filter by genre, author and length or search directly by title. Arthur Conan Doyle, Edgar Allan Poe, H.P. Lovecraft and many more. " />
#     <meta property="og:image" content="https:&#x2F;&#x2F;evanclewisimages.s3.ap-southeast-2.amazonaws.com&#x2F;library_og.jpg" />
#     <meta property="og:image:alt" content="A collage of dramatic images and a logo underneath depicting several books and the title &quot;Library of Short Stories&quot;" />
#
#
#     <meta property="og:url" content=https:&#x2F;&#x2F;www.libraryofshortstories.com&#x2F;stories />
#     <meta property="og:locale" content=en_AU />
#     <meta property="og:type" content=website />
#
#
#     <link rel="preconnect" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com">
#     <link rel="preload" href="/dist/stories_bundle.js" as='script'>
#
#     <link rel="stylesheet" href="/styles/style.css">
#     <link rel="stylesheet" href="/styles/pages/stories.css">
#
#     <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/browsing.jpg" as='image'>
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/fist.jpg" as='image'>
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/telephone.jpg" as='image'>
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/gentleman.jpg" as='image'>
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/stare.jpg" as='image'>
#
#
# </head>
#
# <body>
#     <script src="/dist/stories_bundle.js"></script>
# </body>
#
# </html>

# %%
driver = webdriver.Safari()

# %%
driver.get(url)

# %%
print(driver.page_source)
# Out:
# <html lang="en"><head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta name="application-name" content="library-of-short-stories">
#     <title>The Library - Library of Short Stories</title>
#     <meta name="description" content="Filter by genre, author and length or search directly by title. Arthur Conan Doyle, Edgar Allan Poe, H.P. Lovecraft and many more. ">
#     <meta name="web_author" content="Evan Lewis">
#     <meta name="keywords" content="Short Stories, read online, classics, library, public domain, free, Edgar Allan Poe, H P Lovecraft, Roald Dahl">
#
#     <link rel="apple-touch-icon" sizes="180x180" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-180x180.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-16x16.png">
#     <link rel="icon" type="image/png" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-32x32.png">
#     <link rel="shortcut icon" href="/favicon.ico">
#     <link rel="shortcut icon" sizes="16x16" href="/favicon.ico-16x16">
#     <meta name="msapplication-TileImage" content="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-144x144.png">
#
#     <link rel="canonical" href="https://www.libraryofshortstories.com/stories">
#
#     <meta property="og:title" content="The Library - Library of Short Stories">
#     <meta property="og:description" content="Filter by genre, author and length or search directly by title. Arthur Conan Doyle, Edgar Allan Poe, H.P. Lovecraft and many more. ">
#     <meta property="og:image" content="https://evanclewisimages.s3.ap-southeast-2.amazonaws.com/library_og.jpg">
#     <meta property="og:image:alt" content="A collage of dramatic images and a logo underneath depicting several books and the title &quot;Library of Short Stories&quot;">
#
#
#     <meta property="og:url" content="https://www.libraryofshortstories.com/stories">
#     <meta property="og:locale" content="en_AU">
#     <meta property="og:type" content="website">
#
#
#     <link rel="preconnect" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com">
#     <link rel="preload" href="/dist/stories_bundle.js" as="script">
#
#     <link rel="stylesheet" href="/styles/style.css">
#     <link rel="stylesheet" href="/styles/pages/stories.css">
#
#     <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/browsing.jpg" as="image">
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/fist.jpg" as="image">
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/telephone.jpg" as="image">
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/gentleman.jpg" as="image">
# <link rel="preload" href="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/stare.jpg" as="image">
#
#
# </head>
#
# <body><div id="website" class="website light_mode   "><div class="top_section unsticky"><header id="top_bar" class="top_bar"><div class="title_and_logo_wrapper"><a href="/" class="title_and_logo"><img src="https://libraryofshortstories.s3.ap-southeast-2.amazonaws.com/small/books-180x180.png" alt="A pixel image of differently coloured books." class="logo"><div class="title"><span class="logo_l">L</span><span class="logo_i">i</span><span class="logo_b">b</span>rary of Short Stories</div></a></div></header><nav class="page_bar"><div class="pages"><a href="/" class="menu_title d_computer ">Home</a><a href="/stories" class="menu_title  active">Library</a><a href="/authors" class="menu_title  ">Authors</a><div id="Menu_section_Discover" class="remove_button_styling menu_section  "><a href="/discover" class="remove_button_styling menu_title">Discover</a><div id="Discover" class="dropdown"><a href="/discover" class="page_link  ">Discover</a><div class="separate_top white_border"></div><a href="/classics" class="page_link  ">The Classics</a><a href="/choice" class="page_link  ">Librarian’s Picks</a><div class="separate_top white_border"></div><a href="/genres" class="page_link  ">Best of Genre</a><a href="/collections" class="page_link  ">Themed Collections</a><a href="/reviews" class="page_link  ">Recommended</a></div></div><div id="Menu_section_About" class="remove_button_styling menu_section  "><a href="/about" class="remove_button_styling menu_title">About</a><div id="About" class="dropdown"><a href="/about" class="page_link  ">The Website</a><a href="/about-the-stories" class="page_link  ">The Stories</a><a href="/furtherreading" class="page_link  ">Further Reading</a><a href="/how-to-use" class="page_link  ">Accessibility</a><a href="/privacy" class="page_link  ">Privacy</a></div></div></div></nav><button id="dark-toggle" title="Light mode" class="dark_mode_button"><svg xmlns="http://www.w3.org/2000/svg" width="22" height="32" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" fill="none" stroke-linecap="round" stroke-linejoin="round" class="icon icon-tabler icon-tabler-sun"><path stroke="none" d="M0 0h24v24H0z" fill="none"></path><circle cx="12" cy="12" r="4"></circle><path d="M3 12h1m8 -9v1m8 8h1m-9 8v1m-6.4 -15.4l.7 .7m12.1 -.7l-.7 .7m0 11.4l.7 .7m-12.1 -.7l-.7 .7"></path></svg></button><button title="Settings" class="settings_button"><svg xmlns="http://www.w3.org/2000/svg" width="22" height="32" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" fill="none" stroke-linecap="round" stroke-linejoin="round" class="icon icon-tabler icon-tabler-settings"><path stroke="none" d="M0 0h24v24H0z" fill="none"></path><path d="M10.325 4.317c.426 -1.756 2.924 -1.756 3.35 0a1.724 1.724 0 0 0 2.573 1.066c1.543 -.94 3.31 .826 2.37 2.37a1.724 1.724 0 0 0 1.065 2.572c1.756 .426 1.756 2.924 0 3.35a1.724 1.724 0 0 0 -1.066 2.573c.94 1.543 -.826 3.31 -2.37 2.37a1.724 1.724 0 0 0 -2.572 1.065c-.426 1.756 -2.924 1.756 -3.35 0a1.724 1.724 0 0 0 -2.573 -1.066c-1.543 .94 -3.31 -.826 -2.37 -2.37a1.724 1.724 0 0 0 -1.065 -2.572c-1.756 -.426 -1.756 -2.924 0 -3.35a1.724 1.724 0 0 0 1.066 -2.573c-.94 -1.543 .826 -3.31 2.37 -2.37c1 .608 2.296 .07 2.572 -1.065z"></path><circle cx="12" cy="12" r="3"></circle></svg></button></div><div class="page stories_page"><div class="search_and_filter"><div class="header "><h1 class="default_h1">The Library</h1><h2 class="default_h2">Read from 1000+ Short Stories.</h2></div><div class="centre stories_section_a"><div class="search_then_filter "><div class="search_bar"><div class="input absolute_centre "><input id="story_search" placeholder="Search" class="general_input search_input"><svg xmlns="http://www.w3.org/2000/svg" width="44" height="44" viewBox="0 0 24 24" stroke-width="1.5" stroke="currentColor" fill="none" stroke-linecap="round" stroke-linejoin="round" class="icon icon-tabler icon-tabler-search search_glass "><path stroke="none" d="M0 0h24v24H0z" fill="none"></path><circle cx="10" cy="10" r="7"> ...
#
#
# </body></html>

# %%
from selenium.webdriver.common.by import By
elements = driver.find_elements(By.CSS_SELECTOR, ".story_tiles")

# %%
for element in elements:
    link = element.find_element("css selector", "a").text
    print(link)
# Out:
# The £1,000,000 Bank-NoteMark TwainPublished 1893 in The £1,000,000 Bank-note and Other New Stories8,226 words - 33 minutesA man is given a bank note worth £1,000,000 as a bet to see whether it would be usable without arousing suspicion.Quirky‘Give me the change, please.’
